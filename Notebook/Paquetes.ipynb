# %%
#Un paquete son colecciones de modulos, tambien se les llama libreria
#Instalar libreria
#1. Vamos a la terminal
#2. Escribimos "python3 -m pip install <nombre_libreria>"
# -En este caso se instala la libreria PANDAS
# Out:
# h

# %%
import pandas as pd

#Diccionario de ventas
sales = {'user_id': ['KM37', 'PR19', 'YU88'],
         'order_value': ['197.75', '208.21', '134.99']}

#Usamos Pandas para hacer una hoja similar a excel
sales_df = pd.DataFrame(sales)

print(sales_df)
# Out:
#   user_id order_value
# 0    KM37      197.75
# 1    PR19      208.21
# 2    YU88      134.99

# %%
#Leer un archivo CSV en nuestro directorio actual

sales_df = pd.read_csv('Libro1.csv')
print(sales_df)
# Out:
#      Marca      Modelo
# 0      BMW          M3
# 1  Bugatti      Chiron
# 2  Ferrari  Testarrosa
# 3  Porsche  918 Spyder
# 4   Nissan     GTR R32
# 5    Honda         NSX

# %%
#Podemos mostrar solo las primera 5 filas
print(sales_df.head())
#En este caso solo se mostrara hasta la 4 y no la 5
# Out:
#      Marca      Modelo
# 0      BMW          M3
# 1  Bugatti      Chiron
# 2  Ferrari  Testarrosa
# 3  Porsche  918 Spyder
# 4   Nissan     GTR R32

# %%
#Si queremos ver solamente la info del archivo
print(sales_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Marca   6 non-null      object
#  1   Modelo  6 non-null      object
# dtypes: object(2)
# memory usage: 228.0+ bytes
# None
